# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df1=pd.DataFrame(np.array([[0.5368885324779471,0.5313479623824452],
                        [0.6960705693664796,0.6829937304075235],[0.7429831595829992,0.7445141065830722]]),
                 index=["GaussianNB","RandomForestClassifier","GradientBoostingClassifier"],
                 columns=["Validation Accuracy","Test Accuracy"])

# %%
df1.plot(kind = 'bar', 
             alpha = 0.4,               
             width = 0.9,               
             figsize=(9,4),
                rot=0)

# %%
df2=pd.DataFrame(np.array([[0.5313479623824452,0.2699843260188088,0.37656739811912227],
                        [0.6829937304075235,0.4482758620689655,0.5340909090909091],[0.7445141065830722,0.49764890282131663,0.5983542319749217]]),
                 index=["GaussianNB","RandomForestClassifier","GradientBoostingClassifier"],
                 columns=["Accuracy - Sonido limpio","Accuracy - con Ruido Gaussiano","Accuracy - con Ruido Ambiente"])

# %%
df2.plot(kind = 'bar', 
             alpha = 0.4,               
             width = 0.9,               
             figsize=(9,4),
                rot=0)

# %%
df3=pd.DataFrame(np.array([0.3, 0.2, 0.4, 0.2, 0.4, 0.5]),
                 index=["General","Amplificador","Eco", "Gritando", "Normal", "Pitch"])

# %%
df3.plot(kind = 'bar', 
             alpha = 0.4,               
             width = 0.9,               
             figsize=(9,4),
                rot=0,
        legend=False)
